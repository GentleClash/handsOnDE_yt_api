# %%
import requests
from dotenv import load_dotenv
import os
from dataclasses import dataclass, field
from typing import Optional, Dict, Any, List
import json
from datetime import datetime
from pprint import pprint
from urllib import parse

os.makedirs("data", exist_ok=True)
os.makedirs("data/raw", exist_ok=True)

# %%
load_dotenv()

@dataclass
class BasicConfig:
    api_key: str = field(default_factory=lambda: os.getenv("GOOGLE_API_KEY", "INVALID"))
    base_url: str = field(default="https://www.googleapis.com/youtube/v3")
    if api_key == "INVALID":
        raise ValueError("GOOGLE_API_KEY environment variable is not set or invalid.")

# %%
# Exploring responses

urldefaults = BasicConfig()
def get_url(endpoint: str, basic_config: BasicConfig, params: Optional[Dict[str, str]] = None) -> str:
    if params is None:
        params = {}
    params['key'] = basic_config.api_key
    url = f"{basic_config.base_url}{endpoint}?{parse.urlencode(params)}"
    return url

temp_dir = "responses/raw/colab/"

def get_response(endpoint: str, params: Optional[Dict[str, str]] = None, dump: bool = False, max_pages: int = 1, base_file_name: Optional[str] = None, basic_config: BasicConfig = BasicConfig()) -> List[Dict[str, Any]]:
    results = []
    page_count = 0
    next_page_token = None

    if base_file_name:
        base_name_for_dump: str = temp_dir + base_file_name.replace('/', '_')
        path = os.path.dirname(base_name_for_dump)
        os.makedirs(path, exist_ok=True)
        base_name_for_dump = f"{base_name_for_dump}_response"

    else:
        base_name_for_dump: str = f"{temp_dir}{endpoint.replace('/', '_')}_response"
        os.makedirs(os.path.dirname(base_name_for_dump), exist_ok=True)


    while page_count < max_pages:
        if next_page_token:
            params = params.copy() if params else {}
            params['pageToken'] = next_page_token
        url = get_url(endpoint, basic_config, params)
        response = requests.get(url)
        if response.status_code != 200:
            raise Exception(f"Error: {response.status_code} - {response.text}")
        data = response.json()
        results.append(data)

        if dump:
            print(f"Dumping page {page_count + 1}...")
            page_suffix: str = f"_page_{page_count+1}"
            timestamp: str = datetime.now().strftime('%Y_%m_%d_%H_%M_%S')
            current_file_name: str = f"{base_name_for_dump}{page_suffix}_{timestamp}.json"

            with open(current_file_name, 'w') as f:
                json.dump(data, f, indent=4)
            print(f"Dumped to: {current_file_name}")

        next_page_token = data.get('nextPageToken')
        if not next_page_token:
            break
        page_count += 1

    return results

# %%
parameters: Dict[str, str] = {
    "part": "snippet",
    "chart": "mostPopular",
    "regionCode": "IN",
}

url = get_url("/videos", parameters)
response = get_response("/videos", parameters, dump=True, max_pages=2)
# Out:
# Dumping page 1...
# Dumped to: responses/raw/_videos_response_page_1_2025_08_15_11_31_11.json
# Dumping page 2...
# Dumped to: responses/raw/_videos_response_page_2_2025_08_15_11_31_11.json

# %%
def extract_field_types(data: List[Dict[str, Any]]) -> List[Any]:
    """Extracts field names and their types from a list of dictionaries."""
    def get_types(obj) -> Any:
        if isinstance(obj, dict):
            fields = {}
            for k, v in obj.items():
                if isinstance(v, dict):
                    fields[k] = get_types(v)
                elif isinstance(v, list) and v:
                    if isinstance(v[0], dict):
                        fields[k] = [get_types(v[0])]
                    else:
                        fields[k] = [type(v[0]).__name__]
                else:
                    fields[k] = type(v).__name__ if v is not None else None
            return fields
        return type(obj).__name__
    return [get_types(item) for item in data]

# %%
fields = extract_field_types(data=response)

# %%
pprint(fields)
# Out:
# [{'etag': 'str',
#   'items': [{'etag': 'str',
#              'id': 'str',
#              'kind': 'str',
#              'snippet': {'categoryId': 'str',
#                          'channelId': 'str',
#                          'channelTitle': 'str',
#                          'defaultAudioLanguage': 'str',
#                          'description': 'str',
#                          'liveBroadcastContent': 'str',
#                          'localized': {'description': 'str', 'title': 'str'},
#                          'publishedAt': 'str',
#                          'tags': ['str'],
#                          'thumbnails': {'default': {'height': 'int',
#                                                     'url': 'str',
#                                                     'width': 'int'},
#                                         'high': {'height': 'int',
#                                                  'url': 'str',
#                                                  'width': 'int'},
#                                         'maxres': {'height': 'int',
#                                                    'url': 'str',
#                                                    'width': 'int'},
#                                         'medium': {'height': 'int',
#                                                    'url': 'str',
#                                                    'width': 'int'},
#                                         'standard': {'height': 'int',
#                                                      'url': 'str',
#                                                      'width': 'int'}},
#                          'title': 'str'}}],
#   'kind': 'str',
#   'nextPageToken': 'str',
#   'pageInfo': {'resultsPerPage': 'int', 'totalResults': 'int'}},
#  {'etag': 'str',
#   'items': [{'etag': 'str',
#              'id': 'str',
#              'kind': 'str',
#              'snippet': {'categoryId': 'str',
#                          'channelId': 'str',
#                          'channelTitle': 'str',
#                          'defaultLanguage': 'str',
#                          'description': 'str',
#                          'liveBroadcastContent': 'str',
#                          'localized': {'description': 'str', 'title': 'str'},
#                          'publishedAt': 'str',
#                          'tags': ['str'],
#                          'thumbnails': {'default': {'height': 'int',
#                                                     'url': 'str',
#                                                     'width': 'int'},
#                                         'high': {'height': 'int',
#                                                  'url': 'str',
#                                                  'width': 'int'},
#                                         'maxres': {'height': 'int',
#                                                    'url': 'str',
#                                                    'width': 'int'},
#                                         'medium': {'height': 'int',
#                                                    'url': 'str',
#                                                    'width': 'int'},
#                                         'standard': {'height': 'int',
#                                                      'url': 'str',
#                                                      'width': 'int'}},
#                          'title': 'str'}}],
#   'kind': 'str',
#   'nextPageToken': 'str',
#   'pageInfo': {'resultsPerPage': 'int', 'totalResults': 'int'},
#   'prevPageToken': 'str'}]

# %%
# using a id from the response to get more details about a video
video_id = response[0]['items'][0]['id']
video_details_params = {
    "part": "snippet,contentDetails,statistics",
    "id": video_id
}
response_details = get_response("/videos", video_details_params, dump=True, max_pages=1, base_file_name="video_response")
# Out:
# Dumping page 1...
# Dumped to: responses/raw/video_response_response_page_1_2025_08_15_11_31_14.json

# %%
extract_field_types(data=response_details)
# Out:
# [{'kind': 'str',
#   'etag': 'str',
#   'items': [{'kind': 'str',
#     'etag': 'str',
#     'id': 'str',
#     'snippet': {'publishedAt': 'str',
#      'channelId': 'str',
#      'title': 'str',
#      'description': 'str',
#      'thumbnails': {'default': {'url': 'str', 'width': 'int', 'height': 'int'},
#       'medium': {'url': 'str', 'width': 'int', 'height': 'int'},
#       'high': {'url': 'str', 'width': 'int', 'height': 'int'},
#       'standard': {'url': 'str', 'width': 'int', 'height': 'int'},
#       'maxres': {'url': 'str', 'width': 'int', 'height': 'int'}},
#      'channelTitle': 'str',
#      'tags': ['str'],
#      'categoryId': 'str',
#      'liveBroadcastContent': 'str',
#      'localized': {'title': 'str', 'description': 'str'},
#      'defaultAudioLanguage': 'str'},
#     'contentDetails': {'duration': 'str',
#      'dimension': 'str',
#      'definition': 'str',
#      'caption': 'str',
#      'licensedContent': 'bool',
#      'contentRating': {},
#      'projection': 'str'},
#     'statistics': {'viewCount': 'str',
#      'likeCount': 'str',
#      'favoriteCount': 'str',
#      'commentCount': 'str'}}],
#   'pageInfo': {'totalResults': 'int', 'resultsPerPage': 'int'}}]

# %% [markdown]
# ### We want to automate the process of fetching trending videos and their details periodically
#
# The most common entities would be video, trending_list
# - for the videos we may want to fetch details like title, description, and statistics including likes, comments, duration, and view count.
# - we may also need some id for each video
# - for the trending list, we may want to fetch details like the list of video ids, titles, and thumbnails, and maybe links to the videos.
# - we can add category in the trending list table.Also the date of first appearance.
# - when updating the list periodically instead of discarding the deleted entries, we may store the video ids, appearance date, duration of trending days, link to video in a separate table.
# - we may include a published on date for each video. Not to be confused with first trend appearance date, we may need to rename the columns.
# - we can also include the language of the video.
#
# ~~ok let's work with that~~
# No, let's pause at that. First let's see properly what is available to use.
# we must go fields -> er, not er -> fields

# %%
import pandas as pd

# %%
response_details = json.load(open("../data/raw/extract/video_details_batch_1_response_page_1_2025_08_16_10_36_41.json", "r"))
response = json.load(open("../data/raw/extract/trend_list_response_page_1_2025_08_16_10_36_39.json", "r"))

# %%
video_fields = pd.json_normalize(response_details, record_path=['items'], meta=['kind', 'etag', ['pageInfo', 'totalResults']], meta_prefix='root_')

# %%
video_fields.columns
# Out:
# Index(['kind', 'etag', 'id', 'snippet.publishedAt', 'snippet.channelId',
#        'snippet.title', 'snippet.description',
#        'snippet.thumbnails.default.url', 'snippet.thumbnails.default.width',
#        'snippet.thumbnails.default.height', 'snippet.thumbnails.medium.url',
#        'snippet.thumbnails.medium.width', 'snippet.thumbnails.medium.height',
#        'snippet.thumbnails.high.url', 'snippet.thumbnails.high.width',
#        'snippet.thumbnails.high.height', 'snippet.thumbnails.standard.url',
#        'snippet.thumbnails.standard.width',
#        'snippet.thumbnails.standard.height', 'snippet.thumbnails.maxres.url',
#        'snippet.thumbnails.maxres.width', 'snippet.thumbnails.maxres.height',
#        'snippet.channelTitle', 'snippet.tags', 'snippet.categoryId',
#        'snippet.liveBroadcastContent', 'snippet.localized.title',
#        'snippet.localized.description', 'snippet.defaultAudioLanguage',
#        'contentDetails.duration', 'contentDetails.dimension',
#        'contentDetails.definition', 'contentDetails.caption',
#        'contentDetails.licensedContent', 'contentDetails.projection',
#        'statistics.viewCount', 'statistics.likeCount',
#        'statistics.favoriteCount', 'statistics.commentCount',
#        'snippet.defaultLanguage', 'root_kind', 'root_etag',
#        'root_pageInfo.totalResults'],
#       dtype='object')

# %%
video_fields
# Out:
#              kind                         etag           id  \
# 0   youtube#video  FTNy7gj2Zd__OtWFRXCCmfbL1Ro  tW3n8r7BxTY
# 1   youtube#video  pbsBDXVN551tMKkrjbydiknYfcg  vEXd4Ke7byM
ippet.thumbnails.default.width  snippet.thumbnails.default.height  ...  \
# 0                                120                                 90  ...
# 1                                120                                 90  ...
# 2                                120                                 90  ...
# 3                                120                                 90  ...
# 4                                120                                 90  ...
# 5                                120                                 90  ...
# 6                                120                                 90  ...
# 7                                120                                 90  ...
# 8                                120                                 90  ...
# 9                                120                                 90  ...
# 10                               120                                 90  ...
# 11                               120                                 90  ...
# 12                               120                                 90  ...
# 13                               120                                 90  ...
# 14                               120                                 90  ...
# 15                               120                                 90  ...
# 16                               120                                 90  ...
# 17                               120                                 90  ...
# 18                               120                                 90  ...
# 19                               120                                 90  ...
# 20                               120                                 90  ...
# 21                               120                                 90  ...
# 22                               120                                 90  ...
# 23                               120                                 90  ...
# 24                               120                                 90  ...
#
#    contentDetails.licensedContent  contentDetails.projection  \
# 0                            True                rectangular
# 1                           False                rectangular
# 2                            True                rectangular
# 3                            True                rectangular
# 4                            True                rectangular
# 5                           False                rectangular
# 6                            True                rectangular
# 7                            True                rectangular
# 8                            True                rectangular
# 9                            True                rectangular
# 10                           True                rectangular
# 11                           True                rectangular
# 12                           True                rectangular
# 13                           True                rectangular
# 14                           True                rectangular
# 15                           True                rectangular
# 16                           True                rectangular
# 17                           True                rectangular
# 18                           True                rectangular
# 19                           True                rectangular
# 20                           True                rectangular
# 21                           True                rectangular
# 22                          False                rectangular
# 23                           True                rectangular
# 24                           True                rectangular
#
#     statistics.viewCount statistics.likeCount  statistics.favoriteCount  \
# 0                 782353                 6768                         0
# 1                3913802                59582                         0
# 2                2032962               111138                         0
# 3                 549274                 5941                         0
# 4                 358962                26177                         0
# 5                1133790                35247                         0
# 6                1457993                 6536                         0
# 7               28932527               369215                         0
# 8                 622623                40226                         0
# 9                 822243                 5480                         0
# 10               3301033                97711                         0
# 11                803454                24965                         0
# 12                783517                 5579                         0
# 13               2117707                63140                         0
# 14               1385227                68723                         0
# 15               1054938                 6802                         0
# 16                261525                 8384                         0
# 17                563932                 7913                         0
# 18                655649                 3115                         0
# 19                539287                21416                         0
# 20                550573                31371                         0
# 21                126988                 2263                         0
# 22                 80045                 1106                         0
# 23                625256                11814                         0
# 24                675282                 4792                         0
#
#     statistics.commentCount snippet.defaultLanguage  \
# 0                       354                     NaN
# 1                      5218                     NaN
# 2                      9642                     NaN
# 3                       299                     NaN
# 4                      2640                     NaN
# 5                       101                      en
# 6                       236                   en-IN
# 7                     10683                      en
# 8                        87                   en-GB
# 9                       191                     NaN
# 10                     4133                     NaN
# 11                     3489                      en
# 12                      290                     NaN
# 13                      930                     NaN
# 14                     4220                     NaN
# 15                      304                     NaN
# 16                       77                     NaN
# 17                      631                     NaN
# 18                      125                     NaN
# 19                     1863                   en-IN
# 20                     3162                     NaN
# 21                      166                     NaN
# 22                       24                     NaN
# 23                     1024                      en
# 24                      280                      en
#
#                     root_kind                    root_etag  \
# 0   youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 1   youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 2   youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 3   youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 4   youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 5   youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 6   youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 7   youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 8   youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 9   youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 10  youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 11  youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 12  youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 13  youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 14  youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 15  youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 16  youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 17  youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 18  youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 19  youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 20  youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 21  youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 22  youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 23  youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
# 24  youtube#videoListResponse  PiFnbm7KSLaPknCMUH1OK7UEMQ0
#
#    root_pageInfo.totalResults
# 0                          25
# 1                          25
# 2                          25
# 3                          25
# 4                          25
# 5                          25
# 6                          25
# 7                          25
# 8                          25
# 9                          25
# 10                         25
# 11                         25
# 12                         25
# 13                         25
# 14                         25
# 15                         25
# 16                         25
# 17                         25
# 18                         25
# 19                         25
# 20                         25
# 21                         25
# 22                         25
# 23                         25
# 24                         25
#
# [25 rows x 43 columns]

# %%
playlist_fields = pd.json_normalize(response, record_path=['items'], meta=['etag', ['pageInfo', 'totalResults'], ['pageInfo', 'resultsPerPage'], 'nextPageToken', 'prevPageToken'], meta_prefix='root_', errors='ignore')

# %%
playlist_fields
# Out:
#             kind                         etag           id  \
# 0  youtube#video  ydTTQnPrnViXOZP2AwuTN6QUqcg  tW3n8r7BxTY
# 1  youtube#video  hs7ac63cANpoUEyqubfVWQiV9UU  vEXd4Ke7byM
# 2  youtube#video  -3N2QvHX7l8H0fGP2ket5QeWtMQ  zx8Qp3ba1lg
# 3  youtube#video  EEhguJ4EpFwLCQz0ueNaWH8b97I  gLdWNFFZHZE
# 4  youtube#video  swNC42E0fm8aYwJbEnH-wKaK1Wk  QrWh3Ww3Zn0
#
#     snippet.publishedAt         snippet.channelId  \
# 0  2025-08-14T14:01:31Z  UCTVqVKB55ABOHWieN2thMsw
# 1  2025-08-15T08:39:20Z  UC-LOdiPoxninevJ0DkleCLg
# 2  2025-08-15T06:30:35Z  UCX8pnu3DYUnx8qy8V_c6oHg
# 3  2025-08-14T22:30:06Z  UCE4Fzpv86mA2LqxiX64VLQw
# 4  2025-08-15T04:30:30Z  UCYBAnESPQtjTWSYsVxN9hJA
#
#                                        snippet.title  \
# 0  A.R. Rahman - Maa Tujhe Salaam (Lyrics) Vande ...
# 1  Thama Teaser Announcement | Ayushmann, Rashmik...
# 2  ZOMBIE BORDER PATROL | QUARANTINE ZONE : THE L...
# 3  🌺 Top 10 Krishna Bhajans 🎶 | Krishna Janmashta...
# 4  Raghu Dakat | Official Teaser | Dev, Idhika, A...
#
#                                  snippet.description  \
# 0  🎶 A.R. Rahman - Maa Tujhe Salaam\nListen Here:...
# 1  Independence Day Special!\nThe No. 1 Hindi fil...
# 2  ZOMBIE BORDER PATROL | QUARANTINE ZONE : THE L...
# 3  🌺 Top 10 Krishna Bhajans 🎶 | Krishna Janmashta...
# 4  বিদ্রোহ যার শিরায়…প্রতিশোধ যার রক্তে \nরঘু ডা...
#
#                    snippet.thumbnails.default.url  \
# 0  https://i.ytimg.com/vi/tW3n8r7BxTY/default.jpg
# 1  https://i.ytimg.com/vi/vEXd4Ke7byM/default.jpg
# 2  https://i.ytimg.com/vi/zx8Qp3ba1lg/default.jpg
# 3  https://i.ytimg.com/vi/gLdWNFFZHZE/default.jpg
# 4  https://i.ytimg.com/vi/QrWh3Ww3Zn0/default.jpg
#
#    snippet.thumbnails.default.width  snippet.thumbnails.default.height  ...  \
# 0                               120                                 90  ...
# 1                               120                                 90  ...
# 2                               120                                 90  ...
# 3                               120                                 90  ...
# 4                               120                                 90  ...
#
#   snippet.categoryId  snippet.liveBroadcastContent  \
# 0                 22                          none
# 1                 24                          none
# 2                 20                          none
# 3                 10                          none
# 4                  1                          none
#
#                              snippet.localized.title  \
# 0  A.R. Rahman - Maa Tujhe Salaam (Lyrics) Vande ...
# 1  Thama Teaser Announcement | Ayushmann, Rashmik...
# 2  ZOMBIE BORDER PATROL | QUARANTINE ZONE : THE L...
# 3  🌺 Top 10 Krishna Bhajans 🎶 | Krishna Janmashta...
# 4  Raghu Dakat | Official Teaser | Dev, Idhika, A...
#
#                        snippet.localized.description  \
# 0  🎶 A.R. Rahman - Maa Tujhe Salaam\nListen Here:...
# 1  Independence Day Special!\nThe No. 1 Hindi fil...
# 2  ZOMBIE BORDER PATROL | QUARANTINE ZONE : THE L...
# 3  🌺 Top 10 Krishna Bhajans 🎶 | Krishna Janmashta...
# 4  বিদ্রোহ যার শিরায়…প্রতিশোধ যার রক্তে \nরঘু ডা...
#
#    snippet.defaultAudioLanguage                    root_etag  \
# 0                            ta  FAPHwboiB69imiE3vZE-iTtNQyc
# 1                         en-IN  FAPHwboiB69imiE3vZE-iTtNQyc
# 2                         en-IN  FAPHwboiB69imiE3vZE-iTtNQyc
# 3                            hi  FAPHwboiB69imiE3vZE-iTtNQyc
# 4                            en  FAPHwboiB69imiE3vZE-iTtNQyc
#
#   root_pageInfo.totalResults  root_pageInfo.resultsPerPage  \
# 0                        200                             5
# 1                        200                             5
# 2                        200                             5
# 3                        200                             5
# 4                        200                             5
#
#    root_nextPageToken root_prevPageToken
# 0              CAUQAA                NaN
# 1              CAUQAA                NaN
# 2              CAUQAA                NaN
# 3              CAUQAA                NaN
# 4              CAUQAA                NaN
#
# [5 rows x 34 columns]

# %%
playlist_fields.columns
# Out:
# Index(['kind', 'etag', 'id', 'snippet.publishedAt', 'snippet.channelId',
#        'snippet.title', 'snippet.description',
#        'snippet.thumbnails.default.url', 'snippet.thumbnails.default.width',
#        'snippet.thumbnails.default.height', 'snippet.thumbnails.medium.url',
#        'snippet.thumbnails.medium.width', 'snippet.thumbnails.medium.height',
#        'snippet.thumbnails.high.url', 'snippet.thumbnails.high.width',
#        'snippet.thumbnails.high.height', 'snippet.thumbnails.standard.url',
#        'snippet.thumbnails.standard.width',
#        'snippet.thumbnails.standard.height', 'snippet.thumbnails.maxres.url',
#        'snippet.thumbnails.maxres.width', 'snippet.thumbnails.maxres.height',
#        'snippet.channelTitle', 'snippet.tags', 'snippet.categoryId',
#        'snippet.liveBroadcastContent', 'snippet.localized.title',
#        'snippet.localized.description', 'snippet.defaultAudioLanguage',
#        'root_etag', 'root_pageInfo.totalResults',
#        'root_pageInfo.resultsPerPage', 'root_nextPageToken',
#        'root_prevPageToken'],
#       dtype='object')

# %%
# Intersection and Comparison of Video and Playlist Fields
common_columns = video_fields.columns.intersection(playlist_fields.columns)
common_columns
# Out:
# Index(['kind', 'etag', 'id', 'snippet.publishedAt', 'snippet.channelId',
#        'snippet.title', 'snippet.description',
#        'snippet.thumbnails.default.url', 'snippet.thumbnails.default.width',
#        'snippet.thumbnails.default.height', 'snippet.thumbnails.medium.url',
#        'snippet.thumbnails.medium.width', 'snippet.thumbnails.medium.height',
#        'snippet.thumbnails.high.url', 'snippet.thumbnails.high.width',
#        'snippet.thumbnails.high.height', 'snippet.thumbnails.standard.url',
#        'snippet.thumbnails.standard.width',
#        'snippet.thumbnails.standard.height', 'snippet.thumbnails.maxres.url',
#        'snippet.thumbnails.maxres.width', 'snippet.thumbnails.maxres.height',
#        'snippet.channelTitle', 'snippet.tags', 'snippet.categoryId',
#        'snippet.liveBroadcastContent', 'snippet.localized.title',
#        'snippet.localized.description', 'snippet.defaultAudioLanguage',
#        'root_etag', 'root_pageInfo.totalResults'],
#       dtype='object')

# %%
# Unique columns
video_fields = video_fields.drop(columns=common_columns)
playlist_fields = playlist_fields.drop(columns=common_columns)
print("Video Fields Unique Columns:")
print(video_fields.columns)
print("Playlist Fields Unique Columns:")
print(playlist_fields.columns)
# Out:
# Video Fields Unique Columns:
# Index(['contentDetails.duration', 'contentDetails.dimension',
#        'contentDetails.definition', 'contentDetails.caption',
#        'contentDetails.licensedContent', 'contentDetails.projection',
#        'statistics.viewCount', 'statistics.likeCount',
#        'statistics.favoriteCount', 'statistics.commentCount',
#        'snippet.defaultLanguage', 'root_kind'],
#       dtype='object')
# Playlist Fields Unique Columns:
# Index(['root_pageInfo.resultsPerPage', 'root_nextPageToken',
#        'root_prevPageToken'],
#       dtype='object')

# %% [markdown]
# This gives us an idea of the specific columns that can be used in er
#
# id -> This is our unique video_id. Must be in videos table
#
# snippet.title, snippet.description, snippet.channelTitle, snippet.categoryId -> These are all core attributes of a video and belong directly in our videos table.
#
# contentDetails.duration -> It will be a column in our videos table.
#
# statistics.viewCount, statistics.likeCount, statistics.commentCount -> These are the metrics we're interested in. They also belong in our videos table.
#
# For linking trend list to videos table, the trend list may contain
# a. video_id -> This will be the foreign key in the trend list table linking back to the videos table.

# %%
# Make a two pass api call 

parameters_trend_list: Dict[str, str] = {
    "part": "snippet",
    "chart": "mostPopular",
    "regionCode": "IN",
}

video_details_params = {
    "part": "snippet,contentDetails,statistics",
    "id": video_id
}

get_trend_list = get_response("/videos", parameters_trend_list, dump=True, max_pages=5, base_file_name="trend_list_response")
videos = response_details[0]['items']


for page in get_trend_list:
    if page.get('items'):
        for item in page['items']:
            video_id = item['id']
            video_details_params['id'] = video_id
            video_details = get_response("/videos", video_details_params, dump=True, max_pages=1, base_file_name=f"video_details_{video_id}")
            if video_details[0].get('items'):
                videos.append(video_details[0]['items'][0])
# Out:
# Dumping page 1...
# Dumped to: responses/raw/trend_list_response_response_page_1_2025_08_15_12_02_42.json
# Dumping page 2...
# Dumped to: responses/raw/trend_list_response_response_page_2_2025_08_15_12_02_43.json
# Dumping page 3...
# Dumped to: responses/raw/trend_list_response_response_page_3_2025_08_15_12_02_43.json
# Dumping page 4...
# Dumped to: responses/raw/trend_list_response_response_page_4_2025_08_15_12_02_43.json
# Dumping page 5...
# Dumped to: responses/raw/trend_list_response_response_page_5_2025_08_15_12_02_44.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_tW3n8r7BxTY_response_page_1_2025_08_15_12_02_44.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_fdWnfzsx-ks_response_page_1_2025_08_15_12_02_44.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_8_4kQftrqiU_response_page_1_2025_08_15_12_02_44.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_CdM7bsa4m6E_response_page_1_2025_08_15_12_02_45.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_v1FAaUxF0kg_response_page_1_2025_08_15_12_02_45.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_Md53wFPNNjI_response_page_1_2025_08_15_12_02_45.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_9kWz9Y-2K98_response_page_1_2025_08_15_12_02_46.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_ueCc-AYUMRs_response_page_1_2025_08_15_12_02_46.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_AhmO-1HD90U_response_page_1_2025_08_15_12_02_46.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_98OQf963hLc_response_page_1_2025_08_15_12_02_46.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_uMek4-PwqWY_response_page_1_2025_08_15_12_02_47.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_DIdwy_uZjCs_response_page_1_2025_08_15_12_02_47.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_F4yBrKYjJ90_response_page_1_2025_08_15_12_02_47.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_HXp8Pi5Jr5E_response_page_1_2025_08_15_12_02_48.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_SZVtt-7DL3A_response_page_1_2025_08_15_12_02_48.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_ZyBLMbK4PEY_response_page_1_2025_08_15_12_02_48.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_jd1jRMyd1yE_response_page_1_2025_08_15_12_02_49.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_3i1vjVpwfUQ_response_page_1_2025_08_15_12_02_49.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_z-97iajU-AM_response_page_1_2025_08_15_12_02_49.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_HVh_heRuy68_response_page_1_2025_08_15_12_02_49.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_VvF-_uzGi5o_response_page_1_2025_08_15_12_02_50.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_wLkM5FR_KSY_response_page_1_2025_08_15_12_02_50.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_QrWh3Ww3Zn0_response_page_1_2025_08_15_12_02_50.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_WRwXAUoSJ6Q_response_page_1_2025_08_15_12_02_51.json
# Dumping page 1...
# Dumped to: responses/raw/video_details_wBiC8f5DrBE_response_page_1_2025_08_15_12_02_51.json

# %%
import pandas as pd

# %%
complete_details = json.load(open("../data/raw/extract/complete_extraction_2025_08_16_16_49_49.json", "r"))
response = complete_details["trend_list"] 
response_details = complete_details["video_details"][0]

# %%
trend_ids = pd.json_normalize(
    response,
    record_path=['items'],
    meta=['etag', 'nextPageToken', 'prevPageToken', 'kind'],
    meta_prefix='root_',
    errors='ignore'
)[['id', 'root_kind', 'root_etag', 'root_nextPageToken', 'root_prevPageToken']]

trend_ids = trend_ids.rename(columns={'id': 'video_id'})

# %%
trend_ids.columns
# Out:
# Index(['video_id', 'root_kind', 'root_etag', 'root_nextPageToken',
#        'root_prevPageToken'],
#       dtype='object')

# %%
response_details
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'L2ED9Fk7hgi8_Sd1M2sWTTQa9gw',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'FcIAmuuX_5n873u59rJGbUQmbJg',
#    'id': 'gLdWNFFZHZE',
#    'snippet': {'publishedAt': '2025-08-14T22:30:06Z',
#     'channelId': 'UCE4Fzpv86mA2LqxiX64VLQw',
#     'title': '🌺 Top 10 Krishna Bhajans 🎶 | Krishna Janmashtami Special 2025 | Nonstop Radha Krishna Songs 🙏',
#     'description': '🌺 Top 10 Krishna Bhajans 🎶 | Krishna Janmashtami Special 2025 | Nonstop Radha Krishna Songs 🙏\n\n00:00 - Krishnaya Vasudevaya\n09:10 - Madhurashtakam\n14:30 - Achyutam Keshavam\n24:30 - Hare Krishna Hare Rama\n33:46 - O Kanha Ab To Murli Ki\n37:33 - Govinda Bolo Hari Gopal Bolo\n41:53 - Shri Krishna Govind Hare Murari\n45:54 - Maadhav Madhusudana\n51:24 - Radhe Govind Krishna Murari\n55:41 - Radhika Manohara\n\n🕉 जय श्री राधे कृष्णा 🌸\nLet these bhajans bring blessings, joy, and devotion into your life. 🙏💫\n\nTitle - Achyutam Keshavam\nSinger - Minakshi Majumdar\nAlbum - Bhakti Sangeet Collection Vol 04\nMUSIC COMPOSERS - Goutam Banerjee\n\nTitle - Adharam Madhuram Madhurashtakam\nSinger - Minakshi Majumdar\nAlbum - Bhakti Sangeet Collection Vol 04\nMUSIC COMPOSERS - Goutam Banerjee\n\nTitle - Hare Krishna Hare\nSinger - Disha Roy\nAlbum - Bhakti Sangeet Collection Vol 04\nMUSIC COMPOSERS - Goutam Banerjee\n\nTitle - O Kanha Ab To Murli Ki\nSinger - Disha Roy\nAlbum - Bhakti Sangeet Collection Vol 04\nMUSIC COMPOSERS - Goutam Banerjee\n\nTitle - Krishnaya Vasudevaya\nSinger - Disha Roy\nAlbum - Bhakti Sangeet Collection Vol 04\nMUSIC COMPOSERS - Goutam Banerjee\n\nTitle -
-sangeet-collection-vol-04\n\nAmazon Music\nBhakti Sangeet Collection Vol 01\nhttps://music.amazon.in/albums/B0DXF6HZXJ\n\nBhakti Sangeet Collection Vol 02\nhttps://music.amazon.in/albums/B0F3DJ836R\n\nBhakti Sangeet Collection Vol 04\nhttps://music.amazon.in/albums/B0FH5FYND8\n\nJio Saavn\nBhakti Sangeet Collection Vol 01\nhttps://www.jiosaavn.com/album/bhakti-sangeet-collection-vol-1/9T4jI1Fv8Tw_\n\nBhakti Sangeet Collection Vol 02\nhttps://www.jiosaavn.com/album/bhakti-sangeet-collection-vol-02/2f2DR2fg44k_\n\nBhakti Sangeet Collection Vol 04\nhttps://www.jiosaavn.com/album/bhakti-sangeet-collection-vol-04/wtRKXrOSSF8_\n\nFor more devotional songs SUBSCRIBE - https://www.youtube.com/@DivineBhajanz?sub_confirmation=1\n\n#DivineBhajans for life the best destination for #KrishnaBhajan #KrishnaJanmashtami #NonStopBhajans #RadheKrishna #AchyutamKeshavam'},
#     'defaultAudioLanguage': 'hi'},
#    'contentDetails': {'duration': 'PT1H2M54S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '1404295',
#     'likeCount': '8845',
#     'favoriteCount': '0',
#     'commentCount': '460'}},
#   {'kind': 'youtube#video',
#    'etag': 'uZlK1l4dY2en6D15SIrrB0sbGfQ',
#    'id': '3MfsZFAeNO8',
#    'snippet': {'publishedAt': '2025-08-16T07:30:15Z',
#     'channelId': 'UC3jMepkLKF8y4iiwWmAB3RA',
#     'title': 'THE BENGAL FILES Official Trailer | Vivek Agnihotri | Abhishek A | Pallavi J | Zee Studios | 5 Sept',
#     'description': 'From the makers of The Kashmir Files and The Tashkent Files, here is the official trailer of THE BENGAL FILES, the powerful conclusion to the trilogy by two-time National Award-winning filmmaker Vivek Ranjan Agnihotri.\n\nA presentation by: Tej Narayan & Snehlatha Agarwal and I Am Buddha\n\nDirected by: Vivek Ranjan Agnihotri\nProduced by: Abhishek Agarwal, Pallavi Joshi and Vivek Ranjan Agnihotri \nWorldwide Release: Zee Studios\nMusic: Zee Music Co.\nStarring: Mithun Chakraborty, Anupam Kher, Pallavi Joshi, Darshan Kumaar, Simratt Kaur\n\nThis September, witness the untold truth of the Hindu genocide.\n\n#TheBengalFiles #RightToLife\n\nStay Updated On:\nhttps://www.facebook.com/ZeeStudios\nhttps://twitter.com/ZeeStudios_\nhttps://www.instagram.com/zeestudiosofficial/\nhttps://www.youtube.com/@ZeeStudiosOfficial',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3MfsZFAeNO8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/3MfsZFAeNO8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/3MfsZFAeNO8/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/3MfsZFAeNO8/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/3MfsZFAeNO8/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Zee Studios',
#     'tags': ['Zee Studios',
#      'Bollywood Cinema',
#      'Hindi Cinema',
#      'Bollywood movie',
#      'Latest bollywood movie',
#      'upcoming bollywood movie',
#      'Promo',
#      'Trailer',
#      'Teaser',
#      'zee',
#      'entertainment',
#      'popular',
#      'famous',
#      'superhit',
#      'Blockbuster movie'],
#     'categoryId': '1',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'THE BENGAL FILES Official Trailer | Vivek Agnihotri | Abhishek A | Pallavi J | Zee Studios | 5 Sept',
#      'description': 'From the makers of The Kashmir Files and The Tashkent Files, here is the official trailer of THE BENGAL FILES, the powerful conclusion to the trilogy by two-time National Award-winning filmmaker Vivek Ranjan Agnihotri.\n\nA presentation by: Tej Narayan & Snehlatha Agarwal and I Am Buddha\n\nDirected by: Vivek Ranjan Agnihotri\nProduced by: Abhishek Agarwal, Pallavi Joshi and Vivek Ranjan Agnihotri \nWorldwide Release: Zee Studios\nMusic: Zee Music Co.\nStarring: Mithun Chakraborty, Anupam Kher, Pallavi Joshi, Darshan Kumaar, Simratt Kaur\n\nThis September, witness the untold truth of the Hindu genocide.\n\n#TheBengalFiles #RightToLife\n\nStay Updated On:\nhttps://www.facebook.com/ZeeStudios\nhttps://twitter.com/ZeeStudios_\nhttps://www.instagram.com/zeestudiosofficial/\nhttps://www.youtube.com/@ZeeStudiosOfficial'},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT3M33S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '463518',
#     'likeCount': '68673',
#     'favoriteCount': '0',
#     'commentCount': '7534'}},
#   {'kind': 'youtube#video',
#    'etag': '7xTdinwdW5_F3FkttErcDam2W98',
#    'id': 'zx8Qp3ba1lg',
#    'snippet': {'publishedAt': '2025-08-15T06:30:35Z',
#     'channelId': 'UCX8pnu3DYUnx8qy8V_c6oHg',
#     'title': 'ZOMBIE BORDER PATROL | QUARANTINE ZONE : THE LAST CHECK',
#     'description': 'ZOMBIE BORDER PATROL | QUARANTINE ZONE : THE LAST CHECK\n\nSubscribe to our Second YouTube Channel: https://www.youtube.com/c/UjjwalGamer\n\n\nShare, Support, Subscribe!!!\nSubscribe: http://bit.ly/technogamerz\nDiscord : https://bit.ly/ujjwaldiscord\nYoutube: https://www.youtube.com/c/TechnoGamerzOfficial\nTwitter:  https://www.twitter.com/ujjwalgamer\nFacebook: https://www.facebook.com/technogamerz\nFacebook Myself: https://www.facebook.com/ujjwalgamer\nInstagram: https://instagram.com/ujjwalgamer\nGoogle Plus: https://plus.google.com/+TechnoGamerzOfficial\nWebsite: https://technogamerz.in/\nMerchandise: https://shop.technogamerz.in/\n\n\nBusiness Email : technogamerzofficial@gmail.com\n\n\nAbout : Techno Gamerz is a YouTube Channel, where you will find gaming videos in Hindi, I hope this video was Useful and you liked it, if you did press the thumbs up button.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zx8Qp3ba1lg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zx8Qp3ba1lg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zx8Qp3ba1lg/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/zx8Qp3ba1lg/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/zx8Qp3ba1lg/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Techno Gamerz',
#     'tags': ['zombie border patrol',
#      'find zombie',
#      'police duty',
#      'simulator',
#      'new game',
#      'funny',
#      'ujjwal',
#      'techno gamerz'],
#     'categoryId': '20',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'ZOMBIE BORDER PATROL | QUARANTINE ZONE : THE LAST CHECK',
#      'description': 'ZOMBIE BORDER PATROL | QUARANTINE ZONE : THE LAST CHECK\n\nSubscribe to our Second YouTube Channel: https://www.youtube.com/c/UjjwalGamer\n\n\nShare, Support, Subscribe!!!\nSubscribe: http://bit.ly/technogamerz\nDiscord : https://bit.ly/ujjwaldiscord\nYoutube: https://www.youtube.com/c/TechnoGamerzOfficial\nTwitter:  https://www.twitter.com/ujjwalgamer\nFacebook: https://www.facebook.com/technogamerz\nFacebook Myself: https://www.facebook.com/ujjwalgamer\nInstagram: https://instagram.com/ujjwalgamer\nGoogle Plus: https://plus.google.com/+TechnoGamerzOfficial\nWebsite: https://technogamerz.in/\nMerchandise: https://shop.technogamerz.in/\n\n\nBusiness Email : technogamerzofficial@gmail.com\n\n\nAbout : Techno Gamerz is a YouTube Channel, where you will find gaming videos in Hindi, I hope this video was Useful and you liked it, if you did press the thumbs up button.'},
#     'defaultAudioLanguage': 'en-IN'},
#    'contentDetails': {'duration': 'PT46M59S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount':

#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tW3n8r7BxTY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/tW3n8r7BxTY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/tW3n8r7BxTY/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/tW3n8r7BxTY/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/tW3n8r7BxTY/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'seventyskye',
#     'tags': ['vande mataram',
#      'maa tujhe salaam',
#      'vande mataram song',
#      'vande mataram lyrics',
#      'lyrics vande mataram',
#      'vande mataram ar rahman',
#      'ar rahman vande mataram',
#      'vande mataram ar rahman lyrics',
#      'ar rahman vande mataram lyrics',
#      'maa tujhe salaam song',
#      'maa tujhe salaam lyrics',
#      'ar rahman maa tujhe salaam',
#      'maa tujhe salaam ar rahman',
#      'ar rahman maa tujhe salaam lyrics',
#      'maa tujhe salaam ar rahman lyrics',
#      'maa tujhe salaam lyrics ar rahman',
#      'lyrics maa tujhe salaam ar rahman',
#      'vande mataram Song'],
#     'categoryId': '22',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'A.R. Rahman - Maa Tujhe Salaam (Lyrics) Vande Mataram',
#      'description': '🎶 A.R. Rahman - Maa Tujhe Salaam\nListen Here: http://bit.ly/4mhcu4p\nDiscover similar songs on Spotify: https://seventyskye.in/spotify\nWe are on: https://linktr.ee/seventyskye\nBe sure to Subscribe and Turn on the bell icon to get notified of our new uploads\n\nFollow Us:\nInstagram: https://www.instagram.com/seventyskye/\nSpotify: https://open.spotify.com/user/31nzgncd2a7x3suxnbcmolin264y?si=d272acc7a49644b7\n\nFollow A.R. Rahman\nhttps://www.instagram.com/arrahman/\nhttps://www.facebook.com/arrahman\nhttps://open.spotify.com/artist/1mYsTxnqsietFxj1OgoGbG\n\nLyrics: A.R. Rahman - Maa Tujhe Salaam\n\nVande mataram, Vande mataram\nVande mataram, Vande mataram\nVande mataram, Vande mataram\nVande mataram, Vande mataram\n\nYahan vahan saara jahan dekh liya hai\nKahi bhi tere jaisa koi nahin hai\nAssi nahin, sau din duniya ghooma hai\nNaahi kaahe tere jaisa koi nahin\n\nMain gaya jahan bhi, bas teri yaad thi\nJo mere saath thi\nmujhko tadpaati rulaati\nSab se pyaari teri soorat\nPyaar hai bas tera, pyaar hi\n\nMaa tujhe salaam, maa tujhe salaam\nAmma tujhe salaam\n\nVande mataram.. Vande mataram\nVande mataram.. Vande mataram\nVande mataram.. Vande mataram\n\nVande mataram.. Vande mataram\nChaand ke pahad me\ntera hoon deewana main\nJhoomu naachoon gaau Tere\npyaar ka taraana main\nJeena nahin soch nahin\nDuniya ki daulat nahin\nBas lootunga tere pyaar ka khazaana\n\nEk nazar jab teri\nHoti hai pyaar ki\nDuniya tab to meri\nChamke damke maheke re\nTera chehra sooraj jaisa\nChaand si thand hai pyaar mein\n\nVande mataram, Vande mataram\nVande mataram, Vande mataram\nVande mataram..\nVande mataram, Vande mataram\nVande mataram.. Vande mataram\n\nTere paas hi main aa raha hoon\nApni baahein khol de\nZor se mujhko gale laga le\nMujhko phir woh pyaar de\n\nTu hi zindagi hai,\ntu hi meri mohabbat hai\nTere hi pairon mein jannat hai\nTu hi dil, tu jaan, amma\nMaa tujhe salaam\nMaa tujhe salaam..\nAmma tujhe salaam\nMaa tujhe salaam..\n\nVande.. mataram, Vande.. mataram, vande\nVande.. mataram, Vande.. mataram, vande\nVande mataram, Vande mataram, vande\nVande mataram, Vande mataram, vande\n\nVande mataram.. Vande mataram\nVande mataram.. Vande mataram\nVande mataram.. Vande mataram\n\nVande mataram.. Vande mataram...\n\n#ARRahman #MaaTujheSalaam #VandeMataram #Lyrics #independenceday #independencedaysong #independencedaystatus #newhindisong #newhindimusic #bollywood #bollywoodsongs #bollwoodsongs \n\nContact for submissions, business inquiries, copyright issues, etc.\nseventyskye@gmail.com'},
#     'defaultAudioLanguage': 'ta'},
#    'contentDetails': {'duration': 'PT6M16S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '822034',
#     'likeCount': '6998',
#     'favoriteCount': '0',
#     'commentCount': '360'}},
#   {'kind': 'youtube#video',
#    'etag': 'ty9oqrRILPG2vE4yOA8jNkNcUzw',
#    'id': 'vEXd4Ke7byM',
#    'snippet': {'publishedAt': '2025-08-15T08:39:20Z',
#     'channelId': 'UC-LOdiPoxninevJ0DkleCLg',
#     'title': 'Thama Teaser Announcement | Ayushmann, Rashmika, Paresh, Nawazuddin| Dinesh | In Cinemas This Diwali',
#     'description': 'Independence Day Special!\nThe No. 1 Hindi film Stree 2 turns 1 today 🎉\n\nTo celebrate, Dinesh Vijan expands the Maddock Horror-Comedy Universe with THAMA.\n\nThe World of Thama unveils Tuesday, Aug 19 — your first glimpse at the sarvashaktishaali villain set to redefine fear.\nThe film storms into cinemas this Diwali 2025.\n\nBrace yourself — this chapter is a love story, wilder and deadlier than anything you’ve seen before.\n\n#WorldOfThama #MaddockFilms #Diwali2025\n\nFeaturing: \u202aAyushmann Khurrana\u202c, Rashmika Mandanna, Paresh Rawal & Nawazuddin Siddiqui\nDirected by: Aditya Sarpotdar\nProduced by: Dinesh Vijan & Amar Kaushik\nWritten By: Niren Bhatt, Suresh Mathew & Arun Falara \nCo-Producers: Sharada Karki Jalota & Pooja Prem Patheja \nMusic Composer: Sachin–Jigar\nLyrics: Amitabh Bhattacharya\n\n#AyushmannKhurrana #RashmikaMandanna #PareshRawal #NawazuddinSiddiqui #DineshVijan #Thama #diwali2025\n\nFollow us on:\nInstagram: https://www.instagram.com/maddockfilms/\nTwitter: https://x.com/MaddockFilms\nFacebook: https://www.facebook.com/maddockfilms\nThreads: https://www.threads.net/@maddockfilms',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vEXd4Ke7byM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vEXd4Ke7byM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vEXd4Ke7byM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/vEXd4Ke7byM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/vEXd4Ke7byM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Maddock Films',
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Thama Teaser Announcement | Ayushmann, Rashmika, Paresh, Nawazuddin| Dinesh | In Cinemas This Diwali',
#      'description': 'Independence Day Special!\nThe No. 1 Hindi film Stree 2 turns 1 today 🎉\n\nTo celebrate, Dinesh Vijan expands the Maddock Horror-Comedy Universe with THAMA.\n\nThe World of Thama unveils Tuesday, Aug 19 — your first glimpse at the sarvashaktishaali villain set to redefine fear.\nThe film storms into cinemas this Diwali 2025.\n\nBrace yourself — this chapter is a love story, wilder and deadlier than anything you’ve seen before.\n\n#WorldOfThama #MaddockFilms #Diwali2025\n\nFeaturing: \u202aAyushmann Khurrana\u202c, Rashmika Mandanna, Paresh Rawal & Nawazuddin Siddiqui\nDirected by: Aditya Sarpotdar\nProduced by: Dinesh Vijan & Amar Kaushik\nWritten By: Niren Bhatt, Suresh Mathew & Arun Falara \nCo-Producers: Sharada Karki Jalota & Pooja Prem Patheja \nMusic Composer: Sachin–Jigar\nLyrics: Amitabh Bhattacharya\n\n#AyushmannKhurrana #RashmikaMandanna #PareshRawal #NawazuddinSiddiqui #DineshVijan #Thama #diwali2025\n\nFollow us on:\nInstagram: https://www.instagram.com/maddockfilms/\nTwitter: https://x.com/MaddockFilms\nFacebook: https://www.facebook.com/maddockfilms\nThreads: https://www.threads.net/@maddockfilms'},
#     'defaultAudioLanguage': 'en-IN'},
#    'contentDetails': {'duration': 'PT43S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '4603624',
#     'likeCount': '78256',
#     'favoriteCount': '0',
#     'commentCount': '6095'}},
#   {'kind': 'youtube#video',
#    'etag': 'xT6JarNoTJY8dUilcnRqI255i2A',
#    'id': 'X-IfpwLfGX4',
#    'snippet': {'publishedAt': '2025-08-16T04:55:54Z',
#     'channelId': 'UCjozuND0dR5sNgNUKJaEcRg',
#     'title': 'Choo Choo Charles Monster Train With Ajay Khutail #shortslive #horrorgaming',
#     'description': 'Choo Choo Charles Monster Train With Ajay Khutail #shortslive #horrorgaming',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/X-IfpwLfGX4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/X-IfpwLfGX4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/X-IfpwLfGX4/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/X-IfpwLfGX4/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/X-IfpwLfGX4/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Ajay Khutail',
#     'categoryId': '20',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Choo Choo Charles Monster Train With Ajay Khutail #shortslive #horrorgaming',
#      'description': 'Choo Choo Charles Monster Train With Ajay Khutail #shortslive #horrorgaming'},
#     'defaultAudioLanguage': 'zxx'},
#    'contentDetails': {'duration': 'PT1H36M21S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '1013055',
#     'likeCount': '10142',
#     'favoriteCount': '0',
#     'commentCount': '4'}},
#   {'kind': 'youtube#video',
#    'etag': '6WgIWR6trWtCmRNLhbRfTCaSoOI',
#    'id': 'Fe9OCr5ODjI',
#    'snippet': {'publishedAt': '2025-08-15T11:30:13Z',
#     'channelId': 'UCA1BfqEptH9CDtIEjuwyuSg',
#     'title': '2025 जन्माष्टमी के नॉनस्टॉप भजन ~New Janmashtami Bhajan ~ Krishna Bhajan 2025~Krishna Ji Ke Bhajan',
#     'description': '2025 जन्माष्टमी के नॉनस्टॉप भजन ~New Janmashtami Bhajan ~ Krishna Bhajan 2025~Krishna Ji Ke Bhajan\n\n\nतो आईए आज पावन हृदय से इस भजन द्वारा जो मांगना है मांग लीजिए। सबकी मनोकामनांए पूर्ण होंगी । 🙏\n\n रोज नए नए भजन सुनने के लिए हमारे साथ जुड़ें रहे व् नए नए भजनों का आनंद उठाये भजन पसंद आये तो कमेंट में \'\' जय श्री श्याम " जरुर लिखें || 🌹🌹\n\n⭐Song : \nTera Kisne Kiya Shringaar Sanware 00:00\nO Kanha! Ab To Murli Ki Madhur Suna Do Taan 08:03\nShri Krishna Govind Hare Murari 16:13\nTeri Banki Ada Ne O Sanware 22:38\nNain
he #bhajans #harekrishna #krishnamurti #krishnaquotes #krishnatemple #god #kanha #krishnabhakti #krishnajanmashtami #krishnavani #bhakti #radharani #follow #radheshyam #krishnaconsciousness #mahadev #krishnaradha #bankebiharitemple #bhaktidarshan #janmashtami\n\n\n➤ यहाँ आपको कृष्णा भजन, लाइव श्रीमद भागवत कथा, भगवान कृष्ण,  के द्वारा बताये गयी सनातन धर्म की कुछ महत्वपूर्ण जानकारी को प्राप्त कर सकते है'},
#     'defaultAudioLanguage': 'en-GB'},
#    'contentDetails': {'duration': 'PT1H6M25S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '589245',
#     'likeCount': '4235',
#     'favoriteCount': '0',
#     'commentCount': '290'}},
#   {'kind': 'youtube#video',
#    'etag': '5iJGfcSNWdqiw2qFXj1hPe0SM24',
#    'id': 'QrWh3Ww3Zn0',
#    'snippet': {'publishedAt': '2025-08-15T04:30:30Z',
#     'channelId': 'UCYBAnESPQtjTWSYsVxN9hJA',
#     'title': 'Raghu Dakat | Official Teaser | Dev, Idhika, Anirban, Sohini | Dhrubo Banerjee | SVF | This Puja',
#     'description': 'বিদ্রোহ যার শিরায়…প্রতিশোধ যার রক্তে \nরঘু ডাকাত আসছে… 🔥\n\nPresenting the official teaser of \n#RaghuDakat, a film by Dhrubo Banerjee. \n\nBrace yourself for an epic journey, #ThisPuja ✨\n\n#Pujo2025\n\nFollow on BookMyShow:\nhttps://in.bookmyshow.com/movies/raghu-dakat/ET00428268\n\n🎥 Credits :\n\nFilm: Raghu Dakat\nDirector & Writer: Dhrubo Banerjee\nCast: Dev, Anirban Bhattacharya, Sohini Sarkar, Idhika Paul, Roopa Ganguly\nEditor: Md. Kalam\nCinematographer: Soumik Halder\nWriter: Sugata Guha & Dhrubo Banerjee\nMusic:  @Nilayan  \u200b\u2060& \u200b\u2060 @rathijitvocalart8999 \nScreenplay: Sugata Guha & Dhrubo Banerjee\nSound Design - Adeep Singh Manki\nSound Mix- Anindit Roy (CAS)\n \n\nTeaser Music Credits:\n\nOriginal Background score: Rathijit Bhattacharjee \nKids vocal: Shreehan , Ayushman , Shubhra , soumyalyo , Baidurjya , \nMale voices: Rathijit , Ankit , Soumyabrata \nStem mix: Antarip Adhikary recorded by —Suman Das\nPromo design: Mandar Banerjee\n\nStay Tuned with Dev Entertainment Ventures:\n\n■ Facebook: https://www.facebook.com/deventertainmentventures/\n■ Twitter: https://twitter.com/devpl_official\n■ YouTube: https://www.youtube.com/deventertainmentventuresofficial\n■ Instagram: https://www.instagram.com/deventertainmentventures\n■ Website: http://www.deventertainment.in',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QrWh3Ww3Zn0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QrWh3Ww3Zn0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QrWh3Ww3Zn0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/QrWh3Ww3Zn0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/QrWh3Ww3Zn0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Dev Entertainment Ventures',
#     'tags': ['Bangla Cinema',
#      'Latest Bengali Film',
#      'bengali film new',
#      'latest bengali movies',
#      'dev actor bengali movie',
#      'Kolkata',
#      'Bengali Cinema',
#      'Bengali Films',
#      'New Bengali Films',
#      'dev actor',
#      'dev bengali actor',
#      'new bengali movie',
#      'kolkata movie',
#      'bangla movie',
#      'trending',
#      'dev action movie',
#      'latest trailers',
#      'dev new film',
#      'bengali action movie',
#      'trailer',
#      'new trailer',
#      'raghu dakat',
#      'pujo 2025',
#      'idhika',
#      'sohini',
#      'anirban',
#      'new trailer 2025',
#      'new teaser 2025',
#      'pre tease',
#      'dhrubo banerjee',
#      'devpl',
#      'raghu dakat teaser'],
#     'categoryId': '1',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Raghu Dakat | Official Teaser | Dev, Idhika, Anirban, Sohini | Dhrubo Banerjee | SVF | This Puja',
#      'description': 'বিদ্রোহ যার শিরায়…প্রতিশোধ যার রক্তে \nরঘু ডাকাত আসছে… 🔥\n\nPresenting the official teaser of \n#RaghuDakat, a film by Dhrubo Banerjee. \n\nBrace yourself for an epic journey, #ThisPuja ✨\n\n#Pujo2025\n\nFollow on BookMyShow:\nhttps://in.bookmyshow.com/movies/raghu-dakat/ET00428268\n\n🎥 Credits :\n\nFilm: Raghu Dakat\nDirector & Writer: Dhrubo Banerjee\nCast: Dev, Anirban Bhattacharya, Sohini Sarkar, Idhika Paul, Roopa Ganguly\nEditor: Md. Kalam\nCinematographer: Soumik Halder\nWriter: Sugata Guha & Dhrubo Banerjee\nMusic:  @Nilayan  \u200b\u2060& \u200b\u2060 @rathijitvocalart8999 \nScreenplay: Sugata Guha & Dhrubo Banerjee\nSound Design - Adeep Singh Manki\nSound Mix- Anindit Roy (CAS)\n \n\nTeaser Music Credits:\n\nOriginal Background score: Rathijit Bhattacharjee \nKids vocal: Shreehan , Ayushman , Shubhra , soumyalyo , Baidurjya , \nMale voices: Rathijit , Ankit , Soumyabrata \nStem mix: Antarip Adhikary recorded by —Suman Das\nPromo design: Mandar Banerjee\n\nStay Tuned with Dev Entertainment Ventures:\n\n■ Facebook: https://www.facebook.com/deventertainmentventures/\n■ Twitter: https://twitter.com/devpl_official\n■ YouTube: https://www.youtube.com/deventertainmentventuresofficial\n■ Instagram: https://www.instagram.com/deventertainmentventures\n■ Website: http://www.deventertainment.in'},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT1M48S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'true',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '409706',
#     'likeCount': '27751',
#     'favoriteCount': '0',
#     'commentCount': '2739'}},
#   {'kind': 'youtube#video',
#    'etag': 'teyERQjx-qdCY70U595RSHhThuI',
#    'id': 'KKEgIWIwzCQ',
#    'snippet': {'publishedAt': '2025-08-15T15:53:01Z',
#     'channelId': 'UCe31NPEeRGO0hcznx6Tdb-g',
#     'title': 'OG vs NG: Legacies Clash – Final Day | 79th Independence Day Special',
#     'description': 'This is it. No more second chances. \nThe final Battlegrounds await as OGs and NGs go all-in for ultimate BGMI glory.\n\nEvery drop, every shot, every clutch today decides the future of the battleground. \nThere will be heartbreak. There will be history. And when the dust settles, only ONE legacy will rise as the champion. \n\nLegends will fall. Dynasties will be born. \nWelcome to the final chapter of the ultimate clash of generations. \n\n@MortaLyt @goblinbgmi @HunterZGaming7 @NinjaJOD2 @officialscoutop @JONATHANGAMINGYT @8bitMAMBA @8bitbeg4mercy2 @SPowerGaming @DynamoGaming @gdr_destro @VAADHIYAAR @Dr4gonOP @SnaxGaming @MDLvenom @AustinXGaming1 @FsLeviii @Aryan4OG \n\n#BGMI #OGvsNG #LegaciesClash #Esports #BattlegroundsMobileIndia',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KKEgIWIwzCQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/KKEgIWIwzCQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/KKEgIWIwzCQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/KKEgIWIwzCQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/KKEgIWIwzCQ/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'BATTLEGROUNDS MOBILE INDIA',
#     'tags': ['BATTLEGROUNDS MOBILE INDIA',
#      'BATTLEGROUNDSMOBILEINDIA',
#      'BATTLEGROUNDS MOBILE',
#      'BATTLEGROUNDS',
#      'BATTLEGROUNDS MOBILE INDIA OFFICIAL CHANNEL',
#      'BATTLEGROUNDS MOBILE INDIA YOUTUBE',
#      'BGMI',
#      'BATTLEGROUNDS MOBILE INDIA Release date',
#      'BATTLEGROUNDS MOBILE INDIA Teaser',
#      'meme',
#      'memer',
#      'memeit',
#      'battleground',
#      'bgmilive',
#      'bgmi',
#      'bgmiplaynow'],
#     'categoryId': '20',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': 'OG vs NG: Legacies Clash – Final Day | 79th Independence Day Special',
#      'description': 'This is it. No more second chances. \nThe final Battlegrounds await as OGs and NGs go all-in for ultimate BGMI glory.\n\nEvery drop, every shot, every clutch today decides the future of the battleground. \nThere will be heartbreak. There will be history. And when the dust settles, only ONE legacy will rise as the champion. \n\nLegends will fall. Dynasties will be born. \nWelcome to the final chapter of the ultimate clash of generations. \n\n@MortaLyt @goblinbgmi @HunterZGaming7 @NinjaJOD2 @officialscoutop @JONATHANGAMINGYT @8bitMAMBA @8bitbeg4mercy2 @SPowerGaming @DynamoGaming @gdr_destro @VAADHIYAAR @Dr4gonOP @SnaxGaming @MDLvenom @AustinXGaming1 @FsLeviii @Aryan4OG \n\n#BGMI #OGvsNG #LegaciesClash #Esports #BattlegroundsMobileIndia'},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT4H37M15S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '1153738',
#     'likeCount': '35750',
#     'favoriteCount': '0',
#     'commentCount': '133'}},
#   {'kind': 'youtube#video',
#    'etag': 'xm2o9ZmtJYFydKpUwZwrMxRKt24',
#    'id': 'wBiC8f5DrBE',
#    'snippet': {'publishedAt': '2025-08-15T00:30:59Z',
#     'channelId': 'UC06UXRnhvgWfYWnnYq2CYVQ',
#     'title': 'TOP 15 आज बाळ कृष्ण जन्मला | Aaj Bal Krushna Janmala | Shri Krishna Gavalani | Marathi Gavalan',
# ...
#     'defaultAudioLanguage': 'te'},
#    'contentDetails': {'duration': 'PT1M36S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '2578770',
#     'likeCount': '109542',
#     'favoriteCount': '0',
#     'commentCount': '3701'}},
#   {'kind': 'youtube#video',
#    'etag': 'PbsHfz37y1YKXrA_rqI-HDfkvkA',
#    'id': 'VWKUmMtBxYc',
#    'snippet': {'publishedAt': '2025-08-16T03:30:20Z',
#     'channelId': 'UCLm85ASz0gDwLr6KAPc8zWg',
#     'title': 'I Stole NEWEST BRAINROTS in Steal a Brainrot Roblox',
#     'description': 'Follow My Instagram!\nInstagram- https://www.instagram.com/senpaispideryt/\n\nDiscord-https://discord.gg/senpaispider\nMain Channel-  @SenpaiSpider  \n\nBusiness Inquiries - business@teamsenpaispider.com\n\nThanks for watching lol\n#senpaispider',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VWKUmMtBxYc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/VWKUmMtBxYc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/VWKUmMtBxYc/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/VWKUmMtBxYc/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/VWKUmMtBxYc/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'SenpaiUnlimited',
#     'tags': ['senpaispider',
#      'senpaispider new video',
#      'senpaispider pvp',
#      'senpaispider face revel',
#      'senpaispider wither storm',
#      'senpaispider smarty pie',
#      'senpaispider lapatasmp',
#      'senpaispider minecraft',
#      'blox fruit',
#      'roblox blox fruit',
#      'senpai blox fruit',
#      'blox fruits',
#      'sea 2 blox fruit',
#      'sea 3 blox fruit',
#      'steal a brainrot',
#      'steal a brainrot update',
#      'steal a brainrot owner'],
#     'categoryId': '20',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'I Stole NEWEST BRAINROTS in Steal a Brainrot Roblox',
#      'description': 'Follow My Instagram!\nInstagram- https://www.instagram.com/senpaispideryt/\n\nDiscord-https://discord.gg/senpaispider\nMain Channel-  @SenpaiSpider  \n\nBusiness Inquiries - business@teamsenpaispider.com\n\nThanks for watching lol\n#senpaispider'},
#     'defaultAudioLanguage': 'hi'},
#    'contentDetails': {'duration': 'PT21M57S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '325763',
#     'likeCount': '6971',
#     'favoriteCount': '0',
#     'commentCount': '1483'}},
#   {'kind': 'youtube#video',
#    'etag': 'XFIDMCB2ucvED3_4bs-RKx37fUo',
#    'id': 'XyriARNqo2w',
#    'snippet': {'publishedAt': '2025-08-14T00:30:07Z',
#     'channelId': 'UCfxxS-CeyAMY5pzWNe1ykFg',
#     'title': '#sohar | बधइया बाजे हो | पारम्परिक कृष्ण भजन | Arvind Akela Kallu | Bhojpuri Sohar Geet 2025',
#     'description': '► Album :- बधइया बाजे हो \n► Song :- Badhaiya Baje Ho \n► Singer :-  Arvind Akela Kallu\n► Lyrics :- Pawan Pandey \n► Music :- Anjani Singh, Priyanshu Singh\n►Digital Partner - Global Music Junction\n► Label / Company :- Kiran Music Entertainment\n► Digital Partner - Global Music Junction\n► Company/Label - Kallu Official\n►Trade Inqury No - 9044110102\n___________________________________________________________________\n\n► Digital Head - SRD\n\n_________________________________________________________________\n\n► Company Brand :-  Kallu Official\n► Thanks For Watching Our  Channel.\n► Have A Nice Day ...\n► Subscribe For More Updates ...\n\n\nआप सभी भोजपुरी दर्शको को मेरा प्रणाम, मै Arvind Akela Kallu तहे दिल से आप सभी का धन्यबाद करता हूँ ,आप लोगो ने मुझे बहुत प्यार और आशीर्वाद दिया, इसका ,मै बहुत बहुत शुक्रगुजार हूँ , आप सब से अनुरोध है की ,आप सब हमारे इस चैनल Kallu  Official को भी इसी तरह प्यार और आशीर्वाद देते रहिये (प्रणाम )',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XyriARNqo2w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XyriARNqo2w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XyriARNqo2w/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/XyriARNqo2w/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/XyriARNqo2w/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Kallu Official',
#     'tags': ['arvind akela kallu badhaiya baje angane me',
#      'arvind akela kallu',
#      'richa dixit arvind akela kallu',
#      'arvind akela kallu song',
#      'arvind akela kallu hits',
#      'badhaiya baje angan kallu',
#      'arvind akela kallu ka naya gana',
#      'arvind akela kallu sohar songs',
#      'arvind akela kallu new song',
#      'arvind akela kallu shubh ghadi aayo',
#      'arvind akela kallu ji sohar geet',
#      'arvind akela kallu ka sohar geet',
#      'shubh ghadi aayo arvind akela kallu movie',
#      'Kallu Official'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'hi',
#     'localized': {'title': '#sohar | बधइया बाजे हो | पारम्परिक कृष्ण भजन | Arvind Akela Kallu | Bhojpuri Sohar Geet 2025',
#      'description': '► Album :- बधइया बाजे हो \n► Song :- Badhaiya Baje Ho \n► Singer :-  Arvind Akela Kallu\n► Lyrics :- Pawan Pandey \n► Music :- Anjani Singh, Priyanshu Singh\n►Digital Partner - Global Music Junction\n► Label / Company :- Kiran Music Entertainment\n► Digital Partner - Global Music Junction\n► Company/Label - Kallu Official\n►Trade Inqury No - 9044110102\n___________________________________________________________________\n\n► Digital Head - SRD\n\n_________________________________________________________________\n\n► Company Brand :-  Kallu Official\n► Thanks For Watching Our  Channel.\n► Have A Nice Day ...\n► Subscribe For More Updates ...\n\n\nआप सभी भोजपुरी दर्शको को मेरा प्रणाम, मै Arvind Akela Kallu तहे दिल से आप सभी का धन्यबाद करता हूँ ,आप लोगो ने मुझे बहुत प्यार और आशीर्वाद दिया, इसका ,मै बहुत बहुत शुक्रगुजार हूँ , आप सब से अनुरोध है की ,आप सब हमारे इस चैनल Kallu  Official को भी इसी तरह प्यार और आशीर्वाद देते रहिये (प्रणाम )'},
#     'defaultAudioLanguage': 'bh'},
#    'contentDetails': {'duration': 'PT5M48S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '125416',
#     'likeCount': '1904',
#     'favoriteCount': '0',
#     'commentCount': '87'}},
#   {'kind': 'youtube#video',
#    'etag': 'fO_VHTXYbQsUsdfrJiySa7rNNCg',
#    'id': 'pi80E9flpdE',
#    'snippet': {'publishedAt': '2025-08-13T06:19:01Z',
#     'channelId': 'UCurns3oVyr5L-J8YgJAW4wA',
#     'title': 'Border 2 : Trailer | Sunny Deol | Varun Dhawan | Diljit Dosanjh ,Border 2 Teaser ,New Movie Trailer',
#     'description': 'we are Presenting fan made and concept teaser trailer for Border 2 : Trailer | Sunny Deol | Varun Dhawan | Diljit Dosanjh ,Border 2 Teaser ,New Movie Trailer\n\n#BORDER2TRAILER   #SunnyDeol #VarunDhawan #DiljitDosanjh #sanghvicinema #newmovietrailer #sunilshetty #deshbhaktimove \n\n\nDISCLAIMER: This video is created solely for entertainment purposes. It is not an original official teaser or trailer for the movie. This is a fictional (Notion) fan-made trailer, and the actual storyline of the movie may differ from what is shown in this video.\n\n\nTopic Covered:\n\nBorder 2\nBorder 2 concept trailer\nBorder 2 teaser\nBorder 2 trailer\nBorder 2 movie update\nBorder 2 full movie\nBorder 2 war movie\nBorder 2 India Pakistan\nBorder 2 patriotism\nBorder 2 army film\nBorder 2 fan made\nBorder 2 fan trailer\nBorder 2 release date\nBorder 2 emotional scenes\nBorder 2 official trailer\nBorder 2 cast\nBorder 2 leaked teaser\nBorder 2 background score\nBorder 2 action scene\nBorder 2 Bollywood movie\nBorder 2 war drama\nBorder 2 trending video\nBorder 2 viral video\n\n\n\nabout this video:\n\n#Border2 - The War is still going on \n\n"Deshbhakti ki nayi misaal, \'BORDER2\' mein dekho asli veer ki kahani."\nBorder 2: Sunny Deol welcomes Suniel Shetty\'s son Ahan Shetty in war drama\nAhan Shetty has joined the cast of the upcoming war film Border 2, alongside Sunny Deol, Varun Dhawan and Diljit Dosanjh. The film, set for release on January 23, 2026, was announced with a teaser welcoming Shetty to the project.\n\n\nBorder2, Border2Trailer, Border2FanMade, Border2ConceptTrailer, SunnyDeol, JackieShroff, VarunDhawan, BollywoodWarMovie, BollywoodTrailer, BollywoodAction, BollywoodMovies, IndianArmyMovie, WarMovie, PatrioticMovie, BollywoodFanTrailer, FanMadeTrailer, BollywoodBlockbuster, Bollywood2025, DeshBhaktiMovie, IndianSoldiers, BollywoodWarFilm\n\n\nMusic Credit:\n@FuzzekeMusic\nChannel - https://youtube.com/@FuzzekeMusic?si=j5Lahee_2k836w68\n(1) Video to Link: https://youtu.be/yD0mkpwik7M?si=Qdd9zyFypevkx5As\n(2) Video to Link: https://youtu.be/I-rLpTqh3JU?si=n6HlvSqjMxZ6wbOi\n\n\nThe Star Cine Trailer is a web channel intended to promote cinema through films review, interviews, discussions, video essays and analytical compilations. It is intended primarily for the purpose of encouraging informed discussions, criticism and review of cinema and towards such purpose the programs use short extracts of cinematograph films, sounds recording and photographic works. These clips and extracts are of a minimal nature and the use is not intended to interfere in any manner with their commercial exploitation of the compete work by the owners of the copyright. The use of works are in compliance with the fair dealing exception provided under Sec. 52 of the Copyright Act, and we asset our use of the works under the exception provided for criticism and review.\nSoftwares used : Adobe Premiere Pro, After Effects & Photoshop.\nEdited By: Star Cine Trailer \nEmail Me: subodhkumar3671@gmail.com\n\nWe Follow All Youtube Term\'s\n//Let’s Connect: \n► Subscribe To https://youtube.com/@STARCINETRAILER?si=QbKGa3T4P_3IlB4n\n► For inquiries, please contact us at the email below\n► subodhkumar3671@gmail.com',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pi80E9flpdE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pi80E9flpdE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pi80E9flpdE/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/pi80E9flpdE/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'STAR CINE Trailer • 5.2M views 2 hours ago\n\n\n\n...\n',
#     'tags': ['Border 2',
#      'Border 2 movie',
#      'Diljit Dosanjh',
#      'Varun Dhawan',
#      'Border 2 official trailer',
#      'Border 2 trailer',
#      'Border 2 full movie',
#      'sunny deol',
#      'Border 2 teaser',
#      'Border 2 official teaser',
#      'Border 2 release date',
#      'Border 2 sunny deol trailer',
#      'Border 2 hindi trailer',
#      'Border 2 movie trailer',
#      'Border 2 update',
#      'Border 2 Varun Dhawan',
#      'star cine trailer',
#      'new movie trailer'],
#     'categoryId': '1',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en-IN',
#     'localized': {'title': 'Border 2 : Trailer | Sunny Deol | Varun Dhawan | Diljit Dosanjh ,Border 2 Teaser ,New Movie Trailer',
#      'description': 'we are Presenting fan made and concept teaser trailer for Border 2 : Trailer | Sunny Deol | Varun Dhawan | Diljit Dosanjh ,Border 2 Teaser ,New Movie Trailer\n\n#BORDER2TRAILER   #SunnyDeol #VarunDhawan #DiljitDosanjh #sanghvicinema #newmovietrailer #sunilshetty #deshbhaktimove \n\n\nDISCLAIMER: This video is created solely for entertainment purposes. It is not an original official teaser or trailer for the movie. This is a fictional (Notion) fan-made trailer, and the actual storyline of the movie may differ from what is shown in this video.\n\n\nTopic Covered:\n\nBorder 2\nBorder 2 concept trailer\nBorder 2 teaser\nBorder 2 trailer\nBorder 2 movie update\nBorder 2 full movie\nBorder 2 war movie\nBorder 2 India Pakistan\nBorder 2 patriotism\nBorder 2 army film\nBorder 2 fan made\nBorder 2 fan trailer\nBorder 2 release date\nBorder 2 emotional scenes\nBorder 2 official trailer\nBorder 2 cast\nBorder 2 leaked teaser\nBorder 2 background score\nBorder 2 action scene\nBorder 2 Bollywood movie\nBorder 2 war drama\nBorder 2 trending video\nBorder 2 viral video\n\n\n\nabout this video:\n\n#Border2 - The War is still going on \n\n"Deshbhakti ki nayi misaal, \'BORDER2\' mein dekho asli veer ki kahani."\nBorder 2: Sunny Deol welcomes Suniel Shetty\'s son Ahan Shetty in war drama\nAhan Shetty has joined the cast of the upcoming war film Border 2, alongside Sunny Deol, Varun Dhawan and Diljit Dosanjh. The film, set for release on January 23, 2026, was announced with a teaser welcoming Shetty to the project.\n\n\nBorder2, Border2Trailer, Border2FanMade, Border2ConceptTrailer, SunnyDeol, JackieShroff, VarunDhawan, BollywoodWarMovie, BollywoodTrailer, BollywoodAction, BollywoodMovies, IndianArmyMovie, WarMovie, PatrioticMovie, BollywoodFanTrailer, FanMadeTrailer, BollywoodBlockbuster, Bollywood2025, DeshBhaktiMovie, IndianSoldiers, BollywoodWarFilm\n\n\nMusic Credit:\n@FuzzekeMusic\nChannel - https://youtube.com/@FuzzekeMusic?si=j5Lahee_2k836w68\n(1) Video to Link: https://youtu.be/yD0mkpwik7M?si=Qdd9zyFypevkx5As\n(2) Video to Link: https://youtu.be/I-rLpTqh3JU?si=n6HlvSqjMxZ6wbOi\n\n\nThe Star Cine Trailer is a web channel intended to promote cinema through films review, interviews, discussions, video essays and analytical compilations. It is intended primarily for the purpose of encouraging informed discussions, criticism and review of cinema and towards such purpose the programs use short extracts of cinematograph films, sounds recording and photographic works. These clips and extracts are of a minimal nature and the use is not intended to interfere in any manner with their commercial exploitation of the compete work by the owners of the copyright. The use of works are in compliance with the fair dealing exception provided under Sec. 52 of the Copyright Act, and we asset our use of the works under the exception provided for criticism and review.\nSoftwares used : Adobe Premiere Pro, After Effects & Photoshop.\nEdited By: Star Cine Trailer \nEmail Me: subodhkumar3671@gmail.com\n\nWe Follow All Youtube Term\'s\n//Let’s Connect: \n► Subscribe To https://youtube.com/@STARCINETRAILER?si=QbKGa3T4P_3IlB4n\n► For inquiries, please contact us at the email below\n► subodhkumar3671@gmail.com'},
#     'defaultAudioLanguage': 'hi'},
#    'contentDetails': {'duration': 'PT1M16S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '115438',
#     'likeCount': '1681',
#     'favoriteCount': '0',
#     'commentCount': '43'}}],
#  'pageInfo': {'totalResults': 50, 'resultsPerPage': 50}}

# %%
videos = response_details['items']

# %%
videos = pd.json_normalize(videos)

# %%
videos.columns
# Out:
# Index(['kind', 'etag', 'id', 'snippet.publishedAt', 'snippet.channelId',
#        'snippet.title', 'snippet.description',
#        'snippet.thumbnails.default.url', 'snippet.thumbnails.default.width',
#        'snippet.thumbnails.default.height', 'snippet.thumbnails.medium.url',
#        'snippet.thumbnails.medium.width', 'snippet.thumbnails.medium.height',
#        'snippet.thumbnails.high.url', 'snippet.thumbnails.high.width',
#        'snippet.thumbnails.high.height', 'snippet.thumbnails.standard.url',
#        'snippet.thumbnails.standard.width',
#        'snippet.thumbnails.standard.height', 'snippet.thumbnails.maxres.url',
#        'snippet.thumbnails.maxres.width', 'snippet.thumbnails.maxres.height',
#        'snippet.channelTitle', 'snippet.tags', 'snippet.categoryId',
#        'snippet.liveBroadcastContent', 'snippet.localized.title',
#        'snippet.localized.description', 'snippet.defaultAudioLanguage',
#        'contentDetails.duration', 'contentDetails.dimension',
#        'contentDetails.definition', 'contentDetails.caption',
#        'contentDetails.licensedContent', 'contentDetails.projection',
#        'statistics.viewCount', 'statistics.likeCount',
#        'statistics.favoriteCount', 'statistics.commentCount',
#        'snippet.defaultLanguage'],
#       dtype='object')

# %%
videos = videos.rename(columns={
    'snippet.publishedAt': 'published_at',
    'snippet.channelId': 'channel_id',
    'snippet.thumbnails.default.url': 'thumbnail_url',
    'snippet.channelTitle': 'channel_title',
    'snippet.tags': 'tags',
    'snippet.categoryId': 'category_id',
    'snippet.localized.title': 'localized_title',
    'snippet.localized.description': 'localized_description',
    'contentDetails.duration': 'duration',
    'contentDetails.dimension': 'dimension',
    'contentDetails.definition': 'definition',
    'statistics.viewCount': 'view_count',
    'statistics.likeCount': 'like_count',
    'statistics.dislikeCount': 'dislike_count',
    'statistics.favoriteCount': 'favorite_count',
    'statistics.commentCount': 'comment_count',
    'snippet.defaultAudioLanguage': 'default_language'
})

# %%
videos_clean = videos.drop(columns=[col for col in videos.columns if col.startswith(('contentDetails', 'snippet', 'statistics'))])\
                                .drop(columns=['dimension', 'tags', 'definition'])

# %%
videos_clean.columns
# Out:
# Index(['kind', 'etag', 'id', 'published_at', 'channel_id', 'thumbnail_url',
#        'channel_title', 'category_id', 'localized_title',
#        'localized_description', 'default_language', 'duration', 'view_count',
#        'like_count', 'favorite_count', 'comment_count'],
#       dtype='object')

# %%
trend_ids["first_appearance_date"] = pd.to_datetime('today').strftime('%Y-%m-%d')
# trend_ids["last_appearance_date"] = pd.to_datetime('today').strftime('%Y-%m-%d') this will be during loading only

# %%
trend_ids.rename(columns={'video_id': 'id'
                          , 'root_kind': 'kind'
                          , 'root_etag': 'etag'
                          , 'root_nextPageToken': 'nextPageToken'
                          , 'root_prevPageToken': 'prevPageToken'
                          }                 
                 , inplace=True)

# %%
trend_ids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     55 non-null     object
#  1   kind                   55 non-null     object
#  2   etag                   55 non-null     object
#  3   nextPageToken          55 non-null     object
#  4   prevPageToken          50 non-null     object
#  5   first_appearance_date  55 non-null     object
# dtypes: object(6)
# memory usage: 2.7+ KB

# %%
import pyarrow as pa

# %%
trend_ids = trend_ids.astype(
    {
        'id': 'string[pyarrow]',
        'etag': 'string[pyarrow]',
        'nextPageToken': 'string[pyarrow]',
        'prevPageToken': 'string[pyarrow]',
        'kind': 'category'
    }
)
trend_ids["first_appearance_date"] = pd.to_datetime(trend_ids["first_appearance_date"], errors='coerce', format='%Y-%m-%d')\
    .astype(pd.ArrowDtype(pa.date32()))

# %%
trend_ids['first_appearance_date'].dtype
# Out:
# date32[day][pyarrow]

# %%
trend_ids.head()
# Out:
#             id                       kind                         etag  \
# 0  gLdWNFFZHZE  youtube#videoListResponse  E3CNO702CvvsSn8EuQduGSIKOkk
# 1  3MfsZFAeNO8  youtube#videoListResponse  E3CNO702CvvsSn8EuQduGSIKOkk
# 2  zx8Qp3ba1lg  youtube#videoListResponse  E3CNO702CvvsSn8EuQduGSIKOkk
# 3  tW3n8r7BxTY  youtube#videoListResponse  E3CNO702CvvsSn8EuQduGSIKOkk
# 4  vEXd4Ke7byM  youtube#videoListResponse  E3CNO702CvvsSn8EuQduGSIKOkk
#
#   nextPageToken prevPageToken first_appearance_date
# 0        CAUQAA          <NA>            2025-08-16
# 1        CAUQAA          <NA>            2025-08-16
# 2        CAUQAA          <NA>            2025-08-16
# 3        CAUQAA          <NA>            2025-08-16
# 4        CAUQAA          <NA>            2025-08-16

# %%
trend_ids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     55 non-null     string
#  1   kind                   55 non-null     category
#  2   etag                   55 non-null     string
#  3   nextPageToken          55 non-null     string
#  4   prevPageToken          50 non-null     string
#  5   first_appearance_date  55 non-null     date32[day][pyarrow]
# dtypes: category(1), date32[day][pyarrow](1), string(4)
# memory usage: 4.9 KB

# %%
videos_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   kind                   50 non-null     object
#  1   etag                   50 non-null     object
#  2   id                     50 non-null     object
#  3   published_at           50 non-null     object
#  4   channel_id             50 non-null     object
#  5   thumbnail_url          50 non-null     object
#  6   channel_title          50 non-null     object
#  7   category_id            50 non-null     object
#  8   localized_title        50 non-null     object
#  9   localized_description  50 non-null     object
#  10  default_language       44 non-null     object
#  11  duration               50 non-null     object
#  12  view_count             50 non-null     object
#  13  like_count             48 non-null     object
#  14  favorite_count         50 non-null     object
#  15  comment_count          50 non-null     object
# dtypes: object(16)
# memory usage: 6.4+ KB

# %%
videos_clean['published_at'] = pd.to_datetime(videos_clean['published_at'], errors='coerce').dt.date #Get date

videos_clean['published_at'] = videos_clean['published_at'].astype(pd.ArrowDtype(pa.date32())) #Convert

videos_clean['duration'] = pd.to_timedelta(videos_clean['duration'], errors='coerce')\
                            .dt.total_seconds()\
                            .astype('float32[pyarrow]') #Calculate duration in seconds and convert

# %%
videos_clean = videos_clean.astype(
    {
        'kind': 'category',
        'etag': 'string[pyarrow]',
        'id': 'string[pyarrow]',
        'channel_id': 'string[pyarrow]',
        'thumbnail_url': 'string[pyarrow]',
        'channel_title': 'string[pyarrow]',
        'category_id': 'category',
        'localized_title': 'string[pyarrow]',
        'localized_description': 'string[pyarrow]',
        'default_language': 'category',
        'view_count': 'Int64[pyarrow]',
        'like_count': 'Int64[pyarrow]',
        'comment_count': 'Int32[pyarrow]',
    },
)
videos_clean["favorite_count"] = videos_clean["favorite_count"].astype(pd.SparseDtype("int32", 0))

videos_clean.head()
# Out:
#             kind                         etag           id published_at  \
# 0  youtube#video  FcIAmuuX_5n873u59rJGbUQmbJg  gLdWNFFZHZE   2025-08-14
# 1  youtube#video  uZlK1l4dY2en6D15SIrrB0sbGfQ  3MfsZFAeNO8   2025-08-16
# 2  youtube#video  7xTdinwdW5_F3FkttErcDam2W98  zx8Qp3ba1lg   2025-08-15
# 3  youtube#video  KqzRiFAzz6p-S0DJ3hTAX-9VfN8  tW3n8r7BxTY   2025-08-14
# 4  youtube#video  ty9oqrRILPG2vE4yOA8jNkNcUzw  vEXd4Ke7byM   2025-08-15
#
#                  channel_id                                   thumbnail_url  \
# 0  UCE4Fzpv86mA2LqxiX64VLQw  https://i.ytimg.com/vi/gLdWNFFZHZE/default.jpg
# 1  UC3jMepkLKF8y4iiwWmAB3RA  https://i.ytimg.com/vi/3MfsZFAeNO8/default.jpg
# 2  UCX8pnu3DYUnx8qy8V_c6oHg  https://i.ytimg.com/vi/zx8Qp3ba1lg/default.jpg
# 3  UCTVqVKB55ABOHWieN2thMsw  https://i.ytimg.com/vi/tW3n8r7BxTY/default.jpg
# 4  UC-LOdiPoxninevJ0DkleCLg  https://i.ytimg.com/vi/vEXd4Ke7byM/default.jpg
#
#     channel_title category_id  \
# 0  Divine Bhajans          10
# 1     Zee Studios           1
# 2   Techno Gamerz          20
# 3     seventyskye          22
# 4   Maddock Films          24
#
#                                      localized_title  \
# 0  🌺 Top 10 Krishna Bhajans 🎶 | Krishna Janmashta...
# 1  THE BENGAL FILES Official Trailer | Vivek Agni...
# 2  ZOMBIE BORDER PATROL | QUARANTINE ZONE : THE L...
# 3  A.R. Rahman - Maa Tujhe Salaam (Lyrics) Vande ...
# 4  Thama Teaser Announcement | Ayushmann, Rashmik...
#
#                                localized_description default_language  \
# 0  🌺 Top 10 Krishna Bhajans 🎶 | Krishna Janmashta...               hi
# 1  From the makers of The Kashmir Files and The T...               en
# 2  ZOMBIE BORDER PATROL | QUARANTINE ZONE : THE L...            en-IN
# 3  🎶 A.R. Rahman - Maa Tujhe Salaam\nListen Here:...               ta
# 4  Independence Day Special!\nThe No. 1 Hindi fil...            en-IN
#
#    duration  view_count  like_count  favorite_count  comment_count
# 0    3774.0     1404295        8845               0            460
# 1     213.0      463518       68673               0           7534
# 2    2819.0     2622196      126430               0          10740
# 3     376.0      822034        6998               0            360
# 4      43.0     4603624       78256               0           6095

# %%
videos_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   kind                   50 non-null     category
#  1   etag                   50 non-null     string
#  2   id                     50 non-null     string
#  3   published_at           50 non-null     date32[day][pyarrow]
#  4   channel_id             50 non-null     string
#  5   thumbnail_url          50 non-null     string
#  6   channel_title          50 non-null     string
#  7   category_id            50 non-null     category
#  8   localized_title        50 non-null     string
#  9   localized_description  50 non-null     string
#  10  default_language       44 non-null     category
#  11  duration               50 non-null     float[pyarrow]
#  12  view_count             50 non-null     int64[pyarrow]
#  13  like_count             48 non-null     int64[pyarrow]
#  14  favorite_count         1 non-null      Sparse[int32, 0]
#  15  comment_count          50 non-null     int32[pyarrow]
# dtypes: Sparse[int32, 0](1), category(3), date32[day][pyarrow](1), float[pyarrow](1), int32[pyarrow](1), int64[pyarrow](2), string(7)
# memory usage: 95.2 KB
# /tmp/ipykernel_30998/1690785849.py:1: FutureWarning: Allowing arbitrary scalar fill_value in SparseDtype is deprecated. In a future version, the fill_value must be a valid value for the SparseDtype.subtype.
#   videos_clean.info()

# %%
videos_clean['favorite_count'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 50 entries, 0 to 49
# Series name: favorite_count
# Non-Null Count  Dtype
# --------------  -----
# 50 non-null     Sparse[int32, 0]
# dtypes: Sparse[int32, 0](1)
# memory usage: 532.0 bytes
